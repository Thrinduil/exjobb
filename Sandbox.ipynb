# %% [markdown]
# This is a sandbox!

# %%
print "hello world!"
# Out:
# hello world!

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=100000, random_state=42, n_features=100, n_informative=20, n_classes=2)
print X.shape
print y.shape
# Out:
# (100000, 100)
# (100000,)

# %%
from sklearn.datasets import make_blobs
X_blobs, y_blobs = make_blobs(n_samples=1000, n_features=2, centers=4, cluster_std=1.0, random_state=42)
y_blobs[y_blobs==0] = -1
y_blobs[y_blobs==1] = 1
y_blobs[y_blobs==2] = -1
y_blobs[y_blobs==3] = 1
plt.scatter(X_blobs[:,0], X_blobs[:,1], c=y_blobs, cmap=plt.cm.Paired)
plt.show()

# %%
from sklearn.ensemble import ExtraTreesClassifier
et_clf = ExtraTreesClassifier(n_estimators=30, random_state=42, class_weight="auto")

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=50, n_jobs=5, random_state=42, class_weight="auto")
rf_clf_oob = RandomForestClassifier(n_estimators=50, n_jobs=5, random_state=42, class_weight="auto", oob_score=True)

# %%
from sklearn.cross_validation import StratifiedKFold
cv = StratifiedKFold(y, n_folds=5, shuffle=True, random_state=42)

# %% [markdown]
# ## ROC Curves

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)
et_clf.fit(X_train, y_train)
y_score = et_clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_score[:,1])

# %%
fpr.shape
# Out:
# (30,)

# %%
threshold.shape
# Out:
# (30,)

# %%
plt.plot(fpr, tpr)
plt.plot([0,1], [0,1])

# %%
for train, test in cv:
    et_clf.fit(X[train], y[train])
    y_scores = et_clf.predict_proba(X[test])
    fpr, tpr, _ = roc_curve(y[test], y_scores[:,1])
    plt.plot(fpr, tpr)
plt.plot([0,1], [0,1])
plt.show()

# %%
from sklearn.ensemble import ExtraTreesClassifier
et_clf_oob = ExtraTreesClassifier(n_estimators=30, random_state=42,
                                  class_weight="auto", oob_score=True, bootstrap=True)
et_clf_oob.fit(X, y)
oob_score = et_clf_oob.oob_decision_function_
fpr, tpr, threshold = roc_curve(y, oob_score[:,1])
plt.plot(fpr, tpr)
plt.plot([0,1], [0,1])

# %%
from sklearn.metrics import roc_curve, auc
from scipy import interp

def plot_roc_curve(X, y, cv):

    mean_tpr = 0.0
    mean_fpr = np.linspace(0, 1, 100)
    all_tpr = []
    
    for i, (train, test) in enumerate(cv):
        probas_ = rf_clf.fit(X[train], y[train]).predict_proba(X[test])
        fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
        mean_tpr += interp(mean_fpr, fpr, tpr)
        mean_tpr[0] = 0.0
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.3f)' % (i, roc_auc))
    
    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
    
    mean_tpr /= len(cv)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, 'k--',
             label='Mean ROC (area = %0.3f)' % mean_auc, lw=2)
    
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    
    return plt

# %%
plt = plot_roc_curve(X, y, cv)
plt.show()

# %%
y_morf = np.load("y_morf.npy")
X_myfeat_morf = np.load("X_myfeat_morf.npy")
X_myfeat_morf_aa = X_myfeat_morf[:,300:320]
X_myfeat_morf_do = X_myfeat_morf[:,320:325]
X_myfeat_mof_aa_do = np.hstack((X_myfeat_morf_aa, X_myfeat_morf_do))

# %%
cv_morf = StratifiedKFold(y_morf, n_folds=5, shuffle=True, random_state=42)

# %%
plt = plot_roc_curve(X_myfeat_mof_aa_do, y_morf, cv_morf)
plt.show()

# %%
rf_clf_oob.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='auto', criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=5,
#             oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
rf_clf_oob.oob_score_
# Out:
# 0.89839999999999998

# %%
np.sum(rf_clf_oob.feature_importances_)
# Out:
# 1.0000000000000004

# %%
rf_clf_oob.oob_decision_function_.shape
# Out:
# (10000, 2)

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
rf_clf_oob.fit(X_train, y_train).descision_function(X_test)
# Out:
# AttributeError: 'RandomForestClassifier' object has no attribute 'descision_function'
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/dist-packages/IPython/core/ultratb.py", line 759, in structured_traceback
#     records = _fixed_getinnerframes(etb, context, tb_offset)
#   File "/usr/lib/python2.7/dist-packages/IPython/core/ultratb.py", line 242, in _fixed_getinnerframes
#     records  = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python2.7/inspect.py", line 1044, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/usr/lib/python2.7/inspect.py", line 1004, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/usr/lib/python2.7/inspect.py", line 483, in getmodule
#     file = getabsfile(object, _filename)
# ...

# %%
rf_clf_oob.oob_score_
# Out:
# 0.88146666666666662

# %%
rrf_clf_oob.score(X_test, y_test)
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/dist-packages/IPython/core/ultratb.py", line 759, in structured_traceback
#     records = _fixed_getinnerframes(etb, context, tb_offset)
#   File "/usr/lib/python2.7/dist-packages/IPython/core/ultratb.py", line 242, in _fixed_getinnerframes
#     records  = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python2.7/inspect.py", line 1044, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# NameError: name 'rrf_clf_oob' is not defined
#   File "/usr/lib/python2.7/inspect.py", line 1004, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/usr/lib/python2.7/inspect.py", line 483, in getmodule
# ...

# %% [markdown]
# # Tennis Data

# %%
s = 1 #"sunny"
o = 2 #"overcast"
r = 3 #"rain"
h = 2 #"high"
n = 1 #"normal"
st = 2 #"strong"
we = 1 #"weak"
ye = 1 #"yes"
no = -1 #"no"
tennis_data = {"outlook": [s, s, o, r, r, r, o, s, s, r, s, o, o, r, r],
               "humidity": [h, h, h, h, n, n, n, h, n, n, n, h, n, h, n],
               "wind": [we, st, we, we, we, st, st, we, we, we, st, st, we, st, st],
               "play": [no, no, ye, ye, ye, no, ye, no, ye, ye, ye, ye, ye, no, no]}
tennis_data = pd.DataFrame(tennis_data)

# %%
tennis_data
# Out:
#     humidity  outlook  play  wind
# 0          1        1    -1     1
# 1          1        1    -1     2
# 2          1        2     1     1
# 3          1        3     1     1
# 4          2        3     1     1
# 5          2        3    -1     2
# 6          2        2     1     2
# 7          1        1    -1     1
# 8          2        1     1     1
# 9          2        3     1     1
# 10         2        1     1     2
# 11         1        2     1     2
# 12         2        2     1     1
# 13         1        3    -1     2
# 14         2        3    -1     2

# %%
from sklearn.tree import DecisionTreeClassifier
X = tennis_data.as_matrix(["humidity", "outlook", "wind"])
y = tennis_data.as_matrix(["play"])
tree_clf = DecisionTreeClassifier(random_state=42)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=42, splitter='best')

# %%
tree_clf.predict([3, 1, 2])
# Out:
# array([1])

# %%
from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(tree_clf, out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf("tennis.pdf")
# Out:
# True

# %%
X2
# Out:
# array([[1, 1, 2],
#        [1, 1, 1],
#        [2, 1, 2],
#        [3, 1, 2],
#        [3, 2, 2],
#        [3, 2, 1],
#        [2, 2, 1],
#        [1, 1, 2],
#        [1, 2, 2],
#        [3, 2, 2],
#        [1, 2, 1],
#        [2, 1, 1],
#        [2, 2, 2],
#        [3, 1, 1],
#        [3, 2, 1]])
