# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
from sklearn.datasets.california_housing import fetch_california_housing

# %%
cal_housing = fetch_california_housing()
# Out:
# downloading Cal. housing from http://lib.stat.cmu.edu/modules.php?op=modload&name=Downloads&file=index&req=getit&lid=83 to /home/freso388/scikit_learn_data

# %%
X = cal_housing.data
y = cal_housing.target
feat_names = cal_housing.feature_names

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
feat_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
X_bedrms = X[:,3].reshape((20640,1))

# %%
X_bedrms.shape
# Out:
# (20640, 1)

# %%
from sklearn import linear_model
clf = linear_model.Ridge()
clf.fit(X[:10,2].reshape(10,1), y[:10])
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, solver='auto', tol=0.001)

# %%
clf.intercept_
# Out:
# 0.81534805223182794

# %%
plt.scatter(X[:5,2], y[:5])

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

X = cal_housing.data
y = cal_housing.target
feat_names = cal_housing.feature_names

X = X[:10,2].reshape(10,1)
y = y[:10]

x_plot = np.linspace(float(min(X)), float(max(X)), num=100)
X_plot = x_plot.reshape(100,1)

plt.scatter(X, y)

for degree in [1, 2, 3, 5, 10]:
    model = make_pipeline(PolynomialFeatures(degree), Ridge(alpha=1))
    model.fit(X, y)
    y_plot = model.predict(X_plot)
    plt.plot(x_plot, y_plot, label="degree %d" % degree)

# %%
float(min(X))
# Out:
# 4.294117647058823

# %%
X_plot.shape
# Out:
# (6,)

# %%
from sklearn.linear_model import LinearRegression
sns.set_context("paper")
plt.figure(figsize=(8, 6))
x_fake = np.linspace(1, 10, 10)
X_fake = np.linspace(1, 10, 100)
y_fake = [1, 2, 3.5, 5.3, 7.3, 7.9, 7.0, 6.5, 6.2, 6]
plt.scatter(x_fake, y_fake, label="data")
for degree in [1, 2, 12]:
    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    model.fit(x_fake.reshape(10,1), y_fake)
    y_plot = model.predict(X_fake.reshape(100,1))
    plt.plot(X_fake, y_plot, label="degree %d" % degree)
plt.legend(loc='best')
plt.savefig('bias_vs_variance.pdf', bbox_inches='tight')

# %%
for degree in [1, 2, 3, 5, 10]:
    model = make_pipeline(PolynomialFeatures(degree), Ridge(alpha=1))
    model.fit(X_fake.reshape(10,1), y_fake)
    y_plot = model.predict(X_fake.reshape(10,1))
    plt.plot(X_fake, y_plot, label="degree %d" % degree)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-869d74200a70> in <module>()
#       1 for degree in [1, 2, 3, 5, 10]:
#       2     model = make_pipeline(PolynomialFeatures(degree), Ridge(alpha=1))
# ----> 3     model.fit(X_fake.reshape(10,1), y_fake)
#       4     y_plot = model.predict(X_fake.reshape(10,1))
#       5     plt.plot(X_fake, y_plot, label="degree %d" % degree)
#
# ValueError: total size of new array must be unchanged

# %%
np.sin(1)
# Out:
# 0.8414709848078965

# %%
np.sin(np.pi)
# Out:
# 1.2246467991473532e-16

# %%
sin_x = np.linspace(0, np.pi, num=10)

# %%
sin_y = np.sin(sin_x)

# %%
sin_y_noise = []
for y in sin_y:
    sin_y_noise.append(y + np.random.uniform(-0.15, 0.15))

# %%
plt.scatter(sin_x, sin_y_noise)
plt.plot(sin_x, sin_y)

# %%
from sklearn.linear_model import LinearRegression
sns.set_context("paper")
plt.figure(figsize=(8, 6))
sin_x_long = np.linspace(0, np.pi, num=100)
plt.scatter(sin_x, sin_y_noise, label="noisy data")
for degree in [1, 2, 9]:
    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    model.fit(sin_x.reshape(10,1), sin_y_noise)
    sin_y_long = model.predict(sin_x_long.reshape(100,1))
    plt.plot(sin_x_long, sin_y_long, label="degree %d" % degree)
    #plt.plot(sin_x_long, np.sin(sin_x_long), label="True pattern")
plt.legend(loc='best')
plt.savefig('../figures/bias_vs_variance.pdf', bbox_inches='tight')
